# %% [markdown]
# <a href="https://colab.research.google.com/github/Chavi100507/g.211250088/blob/main/TUGAS_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def create_node(key):
    return {
        "key": key,
        "left": None,
        "right": None
    }

def insert(root, key):
    if root is None:
        return create_node(key)
    if key < root["key"]:
        root["left"] = insert(root["left"], key)
    else:
        root["right"] = insert(root["right"], key)
    return root

def search(root, key):
    if root is None:
        return None
    if key == root["key"]:
        return root
    elif key < root["key"]:
        return search(root["left"], key)
    else:
        return search(root["right"], key)

root = None
data = [10, 20, 5, 15]

for x in data:
    root = insert(root, x)

cari = int(input("Masukan angka yang dicari: "))
hasil = search(root, cari)

if hasil:
    print("angka ditemukan:", hasil["key"])
else:
    print("angka tidak ditemukan")
# Out:
# Masukan angka yang dicari: 6
# angka tidak ditemukan

# %% [markdown]
# PSUDOCODE

# %%
RB-SEARCH(T, key):
    node ← root

    while node ≠ NIL:
        if key = node.key:
            return node
        else if key < node.key:
            node ← kiri
        else:
            node ← kanan

    return tidak ditemukan

RB-INSERT(T, key):
    buat node baru (RED)
    masukkan seperti BST
    lakukan perbaikan (fix)

# %% [markdown]
# analisis

# %%
Best Case: 0(1)

Worst Case 0(log n)

Average : 0(log n)

##Kesimpulan

Red-Black Tree lebih cepat dibanding pencarian linear karena memiliki kompleksitas 0(log n).
