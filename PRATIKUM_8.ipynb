# %% [markdown]
# <a href="https://colab.research.google.com/github/Chavi100507/g.211250088/blob/main/PRATIKUM_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Contoh Dynamic Programming
# Fibonacci: Memoization

memo = {}

def fib_memo(n):
    if n in memo:
        return memo[n]

    if n <= 1:
        return n

    memo[n] = fib_memo(n - 1) + fib_memo(n - 2)
    return memo[n]

n = 50
print("Fibonacci:", fib_memo(n))
# Out:
# Fibonacci: 12586269025

# %%
# Contoh DP Bottom-Up Fibonacci
# Dynamic Programming Fibonacci

def fib_dp(n):

    if n <= 1:
        return n

    dp = [0] * (n + 1)

    dp[0] = 0
    dp[1] = 1

    for i in range(2, n + 1):
        dp[i] = dp[i-1] + dp[i-2]

    return dp[n]

n = 50
print("Fibonacci DP:", fib_dp(n))
# Out:
# Fibonacci DP: 12586269025

# %%
# Greedy Coin Change

def coin_change_greedy(coins, amount):

    # Urutkan dari terbesar
    coins.sort(reverse=True)

    result = []

    for coin in coins:

        while amount >= coin:
            amount -= coin
            result.append(coin)

    return result

coins = [100, 50, 25, 10, 5, 1]
amount = 289

hasil = coin_change_greedy(coins, amount)

print("Koin digunakan:", hasil)
print("Jumlah koin:", len(hasil))
# Out:
# Koin digunakan: [100, 100, 50, 25, 10, 1, 1, 1, 1]
# Jumlah koin: 9

# %%
# Coding DP Combination

def count_ways(coins, amount):

    dp = [0] * (amount + 1)

    dp[0] = 1

    for coin in coins:

        for i in range(coin, amount + 1):
            dp[i] += dp[i - coin]

    return dp[amount]

coins = [1, 2, 5]
amount = 5

print("Jumlah kombinasi:", count_ways(coins, amount))
# Out:
# Jumlah kombinasi: 4
