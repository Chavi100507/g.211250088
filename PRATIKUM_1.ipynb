# %% [markdown]
# <a href="https://colab.research.google.com/github/Chavi100507/g.211250088/blob/main/PRATIKUM_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = 8
for i in range (1,n+1):
  print ("Hello word !!!")

# %%
def total(angka ,n):
  jumlah = 0
  for i in range (n):
    jumlah = jumlah + angka [i]
  return jumlah
angka = [5,3,7,9]
n = len (angka)
print(total (angka,n))

# %%
a= 3
b= 2
angka = [(3,2,7),(2,6,8),(5,1,9)]
total = 0

# %%
n = 5
hasil = 1

for i in range(1, n+1):
    hasil = hasil * i

print(hasil)
