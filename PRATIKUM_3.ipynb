# %% [markdown]
# <a href="https://colab.research.google.com/github/Chavi100507/g.211250088/blob/main/PRATIKUM_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
def euclidean_distance(a, b):
  jumlah = 0
  for i in range(len(a)):
    jumlah += (a[i] - b[i]) ** 2
    return math.sqrt(jumlah)
x = [1, 2]
y = [4, 6]
print (euclidean_distance(x, y))

# %%
def manhattan_distance(a, b):
  total = 0
  for i in range(len(a)):
    total += abs(a[i] - b[i])
    return total

print(manhattan_distance([1, 2], [4, 6]))

# %%
import math
def cosine_similarity(a, b):
  dot = sum(a[i] * b[i] for i in range(len(a)))
  norm_a = math.sqrt(sum(x*x for x in a))
  norm_b = math.sqrt(sum(x*x for x in b))
  return dot / (norm_a * norm_b)
print(cosine_similarity([1, 2], [4, 6]))

# %%
def hamming_distance(a, b):
  return sum(1 for i in range(len(a)) if a[i] != b[i])
print (hamming_distance("1011", "1001"))

# %%
from itertools import permutations
data = [1, 2, 3, 4]
for p in permutations (data, 2):
  print(p)
